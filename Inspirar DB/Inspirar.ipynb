-- %% [markdown]
-- # [dbo].[Agenda]

-- %%
USE [Inspirar]
GO

-- %%
/****** Object:  Table [dbo].[Agenda]    Script Date: 25/09/2022 10:13:00 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Agenda](
	[id_agenda] [int] IDENTITY(1,1) NOT NULL,
	[id_usuario] [int] NULL,
	[id_consultante] [int] NULL,
	[fecha_agenda] [date] NULL,
	[hora_agenda] [varchar](100) NULL,
	[lugar_agenda] [varchar](100) NULL,
	[notas_agenda] [varchar](100) NULL,
 CONSTRAINT [PK_Agenda] PRIMARY KEY CLUSTERED 
(
	[id_agenda] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Consulta]

-- %%
/****** Object:  Table [dbo].[Consulta]    Script Date: 25/09/2022 10:13:00 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Consulta](
	[id_consulta] [int] IDENTITY(1,1) NOT NULL,
	[id_usario] [int] NULL,
	[fecha_consulta] [date] NULL,
	[motivo_consulta] [varchar](250) NULL,
	[hProblemaActual_consulta] [varchar](250) NULL,
	[antecedentesCliPat_consulta] [varchar](250) NULL,
	[antecedentesCliNoPat_consulta] [varchar](250) NULL,
	[genograma_consulta] [varchar](250) NULL,
	[planTerapeutico_consulta] [varchar](250) NULL,
	[notas_consulta] [varchar](250) NULL,
	[examenMentIni_consulta] [varchar](250) NULL,
	[historiaFamiliar_consulta] [varchar](250) NULL,
	[id_consultante] [int] NULL,
 CONSTRAINT [PK_Consulta] PRIMARY KEY CLUSTERED 
(
	[id_consulta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Consultante]

-- %%
/****** Object:  Table [dbo].[Consultante]    Script Date: 25/09/2022 10:13:00 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Consultante](
	[id_consultante] [int] IDENTITY(1,1) NOT NULL,
	[id_telefono] [int] NULL,
	[id_direccion] [int] NULL,
	[id_eps] [int] NULL,
	[fechaNacimiento] [date] NULL,
	[nombres_consultante] [varchar](100) NULL,
	[apellidos_consultante] [varchar](100) NULL,
	[tipoDocumento_consultante] [varchar](50) NULL,
	[sexo_consultante] [varchar](50) NULL,
	[genero_consultante] [varchar](50) NULL,
	[estadoCivil_consultante] [varchar](50) NULL,
	[escolaridad_consultante] [varchar](50) NULL,
	[ocupacion_consultante] [varchar](50) NULL,
	[numeroDocumento_consultante] [varchar](50) NULL,
 CONSTRAINT [PK_Consultante] PRIMARY KEY CLUSTERED 
(
	[id_consultante] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Direccion]

-- %%
/****** Object:  Table [dbo].[Direccion]    Script Date: 25/09/2022 10:13:00 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Direccion](
	[id_dirección] [int] IDENTITY(1,1) NOT NULL,
	[nomenclatura_direccion] [varchar](50) NULL,
	[pais_direccion] [varchar](50) NULL,
	[ciudad_direccion] [varchar](50) NULL,
	[localidad_direccion] [varchar](50) NULL,
	[barrio_direccion] [varchar](50) NULL,
 CONSTRAINT [PK_Direccion] PRIMARY KEY CLUSTERED 
(
	[id_dirección] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Empresa]

-- %%
/****** Object:  Table [dbo].[Empresa]    Script Date: 25/09/2022 10:13:00 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Empresa](
	[nit_empresa] [int] IDENTITY(1,1) NOT NULL,
	[telefono_empresa] [int] NULL,
	[direccion_empresa] [int] NULL,
	[nombre_empresa] [varchar](100) NULL,
	[correo_empresa] [varchar](50) NULL,
 CONSTRAINT [PK_Empresa] PRIMARY KEY CLUSTERED 
(
	[nit_empresa] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Eps]

-- %%
/****** Object:  Table [dbo].[Eps]    Script Date: 25/09/2022 10:13:00 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Eps](
	[id_eps] [int] IDENTITY(1,1) NOT NULL,
	[nombre_eps] [varchar](100) NULL,
	[tipoRegimen_eps] [varchar](50) NULL,
 CONSTRAINT [PK_Eps] PRIMARY KEY CLUSTERED 
(
	[id_eps] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Factura]

-- %%
/****** Object:  Table [dbo].[Factura]    Script Date: 25/09/2022 10:13:00 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Factura](
	[id_factura] [int] IDENTITY(1,1) NOT NULL,
	[id_usuario] [int] NULL,
	[id_consultante] [int] NULL,
	[nit_empresa] [int] NULL,
	[fecha_factura] [date] NULL,
	[tipoServicio_factura] [varchar](50) NULL,
	[descripcion_factura] [varchar](50) NULL,
	[valor_factura] [int] NULL,
 CONSTRAINT [PK_Factura] PRIMARY KEY CLUSTERED 
(
	[id_factura] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Rol]

-- %%
/****** Object:  Table [dbo].[Rol]    Script Date: 25/09/2022 10:13:00 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Rol](
	[id_rol] [int] IDENTITY(1,1) NOT NULL,
	[tipo_rol] [varchar](100) NULL,
 CONSTRAINT [PK_Rol] PRIMARY KEY CLUSTERED 
(
	[id_rol] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Telefono]

-- %%
/****** Object:  Table [dbo].[Telefono]    Script Date: 25/09/2022 10:13:00 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Telefono](
	[id_telefono] [int] IDENTITY(1,1) NOT NULL,
	[fijo_telefono] [varchar](10) NULL,
	[celular_telefono] [varchar](10) NULL,
 CONSTRAINT [PK_Telefono] PRIMARY KEY CLUSTERED 
(
	[id_telefono] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 25/09/2022 10:13:00 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[id_usuario] [int] IDENTITY(1,1) NOT NULL,
	[id_telefono] [int] NULL,
	[nombres_usuario] [varchar](100) NULL,
	[apellidos_usuario] [varchar](100) NULL,
	[login_usuario] [varchar](50) NULL,
	[password_usuario] [varchar](50) NULL,
	[correo_usuario] [varchar](50) NULL,
	[tarjetaProf_usuario] [varchar](50) NULL,
	[reTHUS_usuario] [varchar](50) NULL,
 CONSTRAINT [PK_Usuario] PRIMARY KEY CLUSTERED 
(
	[id_usuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario_Rol]

-- %%
/****** Object:  Table [dbo].[Usuario_Rol]    Script Date: 25/09/2022 10:13:00 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario_Rol](
	[id_usuario] [int] NULL,
	[id_rol] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Agenda_Consultante]

-- %%
ALTER TABLE [dbo].[Agenda]  WITH CHECK ADD  CONSTRAINT [FK_Agenda_Consultante] FOREIGN KEY([id_consultante])
REFERENCES [dbo].[Consultante] ([id_consultante])
GO
ALTER TABLE [dbo].[Agenda] CHECK CONSTRAINT [FK_Agenda_Consultante]
GO

-- %% [markdown]
-- # [FK_Agenda_Usuario]

-- %%
ALTER TABLE [dbo].[Agenda]  WITH CHECK ADD  CONSTRAINT [FK_Agenda_Usuario] FOREIGN KEY([id_usuario])
REFERENCES [dbo].[Usuario] ([id_usuario])
GO
ALTER TABLE [dbo].[Agenda] CHECK CONSTRAINT [FK_Agenda_Usuario]
GO

-- %% [markdown]
-- # [FK_Consulta_Consultante]

-- %%
ALTER TABLE [dbo].[Consulta]  WITH CHECK ADD  CONSTRAINT [FK_Consulta_Consultante] FOREIGN KEY([id_consultante])
REFERENCES [dbo].[Consultante] ([id_consultante])
GO
ALTER TABLE [dbo].[Consulta] CHECK CONSTRAINT [FK_Consulta_Consultante]
GO

-- %% [markdown]
-- # [FK_Consulta_Usuario]

-- %%
ALTER TABLE [dbo].[Consulta]  WITH CHECK ADD  CONSTRAINT [FK_Consulta_Usuario] FOREIGN KEY([id_usario])
REFERENCES [dbo].[Usuario] ([id_usuario])
GO
ALTER TABLE [dbo].[Consulta] CHECK CONSTRAINT [FK_Consulta_Usuario]
GO

-- %% [markdown]
-- # [FK_Consultante_Direccion]

-- %%
ALTER TABLE [dbo].[Consultante]  WITH CHECK ADD  CONSTRAINT [FK_Consultante_Direccion] FOREIGN KEY([id_direccion])
REFERENCES [dbo].[Direccion] ([id_dirección])
GO
ALTER TABLE [dbo].[Consultante] CHECK CONSTRAINT [FK_Consultante_Direccion]
GO

-- %% [markdown]
-- # [FK_Consultante_Eps]

-- %%
ALTER TABLE [dbo].[Consultante]  WITH CHECK ADD  CONSTRAINT [FK_Consultante_Eps] FOREIGN KEY([id_eps])
REFERENCES [dbo].[Eps] ([id_eps])
GO
ALTER TABLE [dbo].[Consultante] CHECK CONSTRAINT [FK_Consultante_Eps]
GO

-- %% [markdown]
-- # [FK_Consultante_Telefono]

-- %%
ALTER TABLE [dbo].[Consultante]  WITH CHECK ADD  CONSTRAINT [FK_Consultante_Telefono] FOREIGN KEY([id_telefono])
REFERENCES [dbo].[Telefono] ([id_telefono])
GO
ALTER TABLE [dbo].[Consultante] CHECK CONSTRAINT [FK_Consultante_Telefono]
GO

-- %% [markdown]
-- # [FK_Factura_Consultante]

-- %%
ALTER TABLE [dbo].[Factura]  WITH CHECK ADD  CONSTRAINT [FK_Factura_Consultante] FOREIGN KEY([id_consultante])
REFERENCES [dbo].[Consultante] ([id_consultante])
GO
ALTER TABLE [dbo].[Factura] CHECK CONSTRAINT [FK_Factura_Consultante]
GO

-- %% [markdown]
-- # [FK_Factura_Empresa]

-- %%
ALTER TABLE [dbo].[Factura]  WITH CHECK ADD  CONSTRAINT [FK_Factura_Empresa] FOREIGN KEY([nit_empresa])
REFERENCES [dbo].[Empresa] ([nit_empresa])
GO
ALTER TABLE [dbo].[Factura] CHECK CONSTRAINT [FK_Factura_Empresa]
GO

-- %% [markdown]
-- # [FK_Factura_Usuario]

-- %%
ALTER TABLE [dbo].[Factura]  WITH CHECK ADD  CONSTRAINT [FK_Factura_Usuario] FOREIGN KEY([id_usuario])
REFERENCES [dbo].[Usuario] ([id_usuario])
GO
ALTER TABLE [dbo].[Factura] CHECK CONSTRAINT [FK_Factura_Usuario]
GO

-- %% [markdown]
-- # [FK_Usuario_Rol_Rol]

-- %%
ALTER TABLE [dbo].[Usuario_Rol]  WITH CHECK ADD  CONSTRAINT [FK_Usuario_Rol_Rol] FOREIGN KEY([id_rol])
REFERENCES [dbo].[Rol] ([id_rol])
GO
ALTER TABLE [dbo].[Usuario_Rol] CHECK CONSTRAINT [FK_Usuario_Rol_Rol]
GO

-- %% [markdown]
-- # [FK_Usuario_Rol_Usuario]

-- %%
ALTER TABLE [dbo].[Usuario_Rol]  WITH CHECK ADD  CONSTRAINT [FK_Usuario_Rol_Usuario] FOREIGN KEY([id_usuario])
REFERENCES [dbo].[Usuario] ([id_usuario])
GO
ALTER TABLE [dbo].[Usuario_Rol] CHECK CONSTRAINT [FK_Usuario_Rol_Usuario]
GO
